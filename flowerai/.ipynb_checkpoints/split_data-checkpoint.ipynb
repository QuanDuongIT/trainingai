# %%
import os


# Lấy đường dẫn của thư mục hiện tại
current_dir_path = os.getcwd()

# Chuyển đổi \ thành /
current_dir_path = current_dir_path.replace("\\", "/")

# In ra đường dẫn đã chuyển đổi
print(f"Đường dẫn hiện tại của thư mục (Unix style): {current_dir_path}")
# Out:
# Đường dẫn hiện tại của thư mục (Unix style): C:/Users/TieuDuong/machine_learning/sumDataset

# %%
import os

def print_directory_structure(root_dir, indent_level=0):
    # Tạo khoảng trắng để thụt dòng dựa trên mức độ indent
    indent = '    ' * indent_level
    print(f"{indent}{os.path.basename(root_dir)}/")

    # Duyệt qua tất cả các tệp và thư mục con
    items = os.listdir(root_dir)
    files_printed = 0
    for item in items:
        item_path = os.path.join(root_dir, item)
        
        if os.path.isdir(item_path):
            # Nếu là thư mục, tiếp tục đệ quy
            print_directory_structure(item_path, indent_level + 1)
        else:
            # In ra tối đa 2 tệp
            if files_printed < 2:
                print(f"{indent}    {item}")  # In ra tệp
                files_printed += 1
            elif files_printed == 2:
                print(f"{indent}    ... (còn nhiều tệp khác)")  # Hiển thị thông báo nếu còn nhiều tệp
                break

# Đường dẫn tới thư mục cần in ra cấu trúc
root_directory = current_dir_path

# In ra cấu trúc thư mục với tối đa 2 tệp trong mỗi thư mục
print_directory_structure(root_directory)
# Out:
# sumDataset/
#     .ipynb_checkpoints/
#         prepare_dataset-checkpoint.ipynb
#         split_data-checkpoint.ipynb
#     flower detection.v3i.yolov8/
#         .ipynb_checkpoints/
#             trainyolo-checkpoint.ipynb
#         data.yaml
#         README.dataset.txt
#         ... (còn nhiều tệp khác)
#     flower_detector.v1i.yolov8/
#         data.yaml
#         README.dataset.txt
#         ... (còn nhiều tệp khác)
#     merged_dataset/
#         .ipynb_checkpoints/
#             data-checkpoint.yaml
#             merged_data-checkpoint.yaml
#             ... (còn nhiều tệp khác)
#         data.yaml
#         data2/
#             images/
#                 train/
#                     carnation/
#                         image_06890.jpg
#                         image_06891.jpg
#                         ... (còn nhiều tệp khác)
#                     cyclamen/
#                         image_00446.jpg
#                         image_00448.jpg
#                         ... (còn nhiều tệp khác)
#                 val/
#                     carnation/
#                         image_06892.jpg
#                         image_06895.jpg
#                         ... (còn nhiều tệp khác)
#                     cyclamen/
#                         image_00447.jpg
#                         image_00454.jpg
#                         ... (còn nhiều tệp khác)
#             labels/
#                 .ipynb_checkpoints/
#                     train-checkpoint.txt
#                 train/
#                     carnation/
#                         image_06890.txt
#                         image_06891.txt
#                         ... (còn nhiều tệp khác)
#                     carnation.cache
#                     cyclamen/
#                         image_00446.txt
#                         image_00448.txt
#                         ... (còn nhiều tệp khác)
#                 train.txt
#                 val/
#                     carnation/
#                         image_06892.txt
#                         image_06895.txt
#                         ... (còn nhiều tệp khác)
#                     carnation.cache
#                     cyclamen/
#                         image_00447.txt
#                         image_00454.txt
#                         ... (còn nhiều tệp khác)
#                 val.txt
#         merged_data.yaml
#         runs/
#             detect/
#                 train/
#                     args.yaml
#                     events.out.tfevents.1727791775.DESKTOP-OT84HSS.3056.0
#                     weights/
#                 train10/
#                     args.yaml
#                     events.out.tfevents.1727803921.DESKTOP-OT84HSS.1368.0
#                     ... (còn nhiều tệp khác)
#                 train11/
#                     args.yaml
#                     events.out.tfevents.1727849962.DESKTOP-OT84HSS.2024.0
#                     ... (còn nhiều tệp khác)
#                 train12/
#                     args.yaml
#                     events.out.tfevents.1727850074.DESKTOP-OT84HSS.7336.0
#                     ... (còn nhiều tệp khác)
#                 train13/
#                     args.yaml
#                     events.out.tfevents.1727850503.DESKTOP-OT84HSS.508.0
#                     ... (còn nhiều tệp khác)
#                 train14/
#                     args.yaml
#                     events.out.tfevents.1727850603.DESKTOP-OT84HSS.8156.0
#                     ... (còn nhiều tệp khác)
#                 train15/
#                     args.yaml
#                     events.out.tfevents.1727850908.DESKTOP-OT84HSS.8108.0
#                     ... (còn nhiều tệp khác)
#                 train16/
#                     args.yaml
#                     events.out.tfevents.1727851055.DESKTOP-OT84HSS.8940.0
#                     ... (còn nhiều tệp khác)
#                 train17/
#                     args.yaml
#                     events.out.tfevents.1727851283.DESKTOP-OT84HSS.9836.0
#                     ... (còn nhiều tệp khác)
#                 train18/
#                     args.yaml
#                     events.out.tfevents.1727854755.DESKTOP-OT84HSS.9836.1
#                     ... (còn nhiều tệp khác)
#                 train19/
#                     args.yaml
#                     events.out.tfevents.1727854909.DESKTOP-OT84HSS.9208.0
#                     ... (còn nhiều tệp khác)
#                 train2/
#                     args.yaml
#                     events.out.tfevents.1727797224.DESKTOP-OT84HSS.8008.0
#                     ... (còn nhiều tệp khác)
#                 train3/
#                     args.yaml
#                     events.out.tfevents.1727801374.DESKTOP-OT84HSS.3656.0
#                     ... (còn nhiều tệp khác)
#                 train4/
#                     args.yaml
#                     events.out.tfevents.1727801495.DESKTOP-OT84HSS.10192.0
#                     ... (còn nhiều tệp khác)
#                 train5/
#                     args.yaml
#                     events.out.tfevents.1727802143.DESKTOP-OT84HSS.4076.0
#                     ... (còn nhiều tệp khác)
#                 train6/
#                     args.yaml
#                     events.out.tfevents.1727803052.DESKTOP-OT84HSS.10424.0
#                     ... (còn nhiều tệp khác)
#                 train7/
#                     args.yaml
#                     events.out.tfevents.1727803294.DESKTOP-OT84HSS.2084.0
#                     ... (còn nhiều tệp khác)
#                 train8/
#                     args.yaml
#                     events.out.tfevents.1727803492.DESKTOP-OT84HSS.8840.0
#                     ... (còn nhiều tệp khác)
#                 train9/
#                     args.yaml
#                     events.out.tfevents.1727803649.DESKTOP-OT84HSS.11644.0
#                     ... (còn nhiều tệp khác)
#         split_dataset/
#             part_1/
#                 images/
#                     -10_jpeg.rf.3163f4c50a58a14fa6587afbd9cd316d.jpg
#                     -12_jpeg.rf.2e3e5233e8251f1cb6a02290d9cecec3.jpg
#                     ... (còn nhiều tệp khác)
#                 labels/
#                     -10_jpeg.rf.3163f4c50a58a14fa6587afbd9cd316d.txt
#                     -12_jpeg.rf.2e3e5233e8251f1cb6a02290d9cecec3.txt
#                     ... (còn nhiều tệp khác)
#                 labels.cache
#             part_1.yaml
#             part_10/
#                 images/
#                     -13_jpeg.rf.7499f72e573322c891e8d9e64fb793e2.jpg
#                     -3_jpeg.rf.8d4a6aac331dd11ae9002dd3a13f89f9.jpg
#                     ... (còn nhiều tệp khác)
#                 labels/
#                     -13_jpeg.rf.7499f72e573322c891e8d9e64fb793e2.txt
#                     -3_jpeg.rf.8d4a6aac331dd11ae9002dd3a13f89f9.txt
#                     ... (còn nhiều tệp khác)
#             part_10.yaml
#             part_100/
#                 images/
#                     -53_jpeg.rf.9f68049ffa7be4c19246ae102cf6cbf7.jpg
#                     -66_jpeg.rf.e6ee8da79150371ea82157ce9c3933a6.jpg
#                     ... (còn nhiều tệp khác)
#                 labels/
#                     -53_jpeg.rf.9f68049ffa7be4c19246ae102cf6cbf7.txt
#                     -66_jpeg.rf.e6ee8da79150371ea82157ce9c3933a6.txt
#                     ... (còn nhiều tệp khác)
#             ... (còn nhiều tệp khác)
#         test/
#             images/
#                 -0_jpeg.rf.a6bd7d9ed6eefa16649f05da02f6dc6c.jpg
#                 -11_jpeg.rf.5a23d135ce0b41b32c19565a5af091ba.jpg
#                 ... (còn nhiều tệp khác)
#             labels/
#                 -0_jpeg.rf.a6bd7d9ed6eefa16649f05da02f6dc6c.txt
#                 -11_jpeg.rf.5a23d135ce0b41b32c19565a5af091ba.txt
#                 ... (còn nhiều tệp khác)
#         train/
#             .ipynb_checkpoints/
#             images/
#                 -0_jpeg.rf.399724ca6e701bad90a207b8c8456959.jpg
#                 -0_jpeg.rf.43ca94c5b76ff35594608b5ab8360550.jpg
#                 ... (còn nhiều tệp khác)
#             labels/
#                 -0_jpeg.rf.399724ca6e701bad90a207b8c8456959.txt
#                 -0_jpeg.rf.43ca94c5b76ff35594608b5ab8360550.txt
#                 ... (còn nhiều tệp khác)
#             labels.cache
#         ... (còn nhiều tệp khác)
#     prepare_dataset.ipynb
#     split_data.ipynb
#     syn3.v1i.yolov8/
#         data.yaml
#         README.dataset.txt
#         ... (còn nhiều tệp khác)
#     Test1.v1-v1.yolov8/
#         data.yaml
#         README.dataset.txt
#         ... (còn nhiều tệp khác)
#     yolo4/
#         .ipynb_checkpoints/
#             trainyolo-checkpoint.ipynb
#         data.yaml
#         flower detection.v3i.yolov8/
#             README.dataset.txt
#             README.roboflow.txt
#             test/
#                 images/
#                     -------_11_jpg.rf.c97f7a650aa62e13ba56e1d81d7df27c.jpg
#                     -------_13.rf.0910fedf547d4f1b6aae98fa3ad66a43.jpg
#                     ... (còn nhiều tệp khác)
#                 labels/
#                     -------_11_jpg.rf.c97f7a650aa62e13ba56e1d81d7df27c.txt
#                     -------_13.rf.0910fedf547d4f1b6aae98fa3ad66a43.txt
#                     ... (còn nhiều tệp khác)
#             train/
#                 images/
#                     -------_10.rf.6482165982bfd19d4d8da93b5e2f4461.jpg
#                     -------_10_jpg.rf.5ec6c3b37f5b13e6065359994166d9f0.jpg
#                     ... (còn nhiều tệp khác)
#                 labels/
#                     -------_10.rf.6482165982bfd19d4d8da93b5e2f4461.txt
#                     -------_10_jpg.rf.5ec6c3b37f5b13e6065359994166d9f0.txt
#                     ... (còn nhiều tệp khác)
#                 labels.cache
#             valid/
#                 images/
#                     -------_1.rf.3249c64d2b406b0d7d37075d7e63c349.jpg
#                     -------_11.rf.d33ee65a4d4ef61a43db31d031b6d36f.jpg
#                     ... (còn nhiều tệp khác)
#                 labels/
#                     -------_1.rf.3249c64d2b406b0d7d37075d7e63c349.txt
#                     -------_11.rf.d33ee65a4d4ef61a43db31d031b6d36f.txt
#                     ... (còn nhiều tệp khác)
#                 labels.cache
#         note.ipynb
#         runs/
#             detect/
#                 train/
#                     args.yaml
#                     events.out.tfevents.1727853546.DESKTOP-OT84HSS.1456.0
#                     weights/
#         split_dataset1/
#             part_1/
#                 images/
#                 labels/
#             part_1.yaml
#             part_2/
#                 images/
#                 labels/
#         ... (còn nhiều tệp khác)

# %%
merged_dataset_path = os.path.join(root_directory, 'syn3.v1i.yolov8')

# Sửa lại việc in đường dẫn
print(os.path.join(merged_dataset_path, 'train/images'))
print(os.path.join(merged_dataset_path, 'valid/images'))
print(os.path.join(merged_dataset_path, 'test/images'))
print(os.path.join(merged_dataset_path, 'data.yaml'))
print_directory_structure(merged_dataset_path)
# Out:
# C:/Users/TieuDuong/machine_learning/sumDataset\syn3.v1i.yolov8\train/images
# C:/Users/TieuDuong/machine_learning/sumDataset\syn3.v1i.yolov8\valid/images
# C:/Users/TieuDuong/machine_learning/sumDataset\syn3.v1i.yolov8\test/images
# C:/Users/TieuDuong/machine_learning/sumDataset\syn3.v1i.yolov8\data.yaml
# syn3.v1i.yolov8/
#     data.yaml
#     README.dataset.txt
#     ... (còn nhiều tệp khác)

# %%
import os
import shutil
import random
import yaml  # Thêm import để đọc tệp YAML

def copy_dataset_part(src_images_dir, src_labels_dir, dest_dir, part_num, total_parts):
    # Tạo thư mục cho phần dữ liệu
    part_images_dir = os.path.join(dest_dir, f'part_{part_num}/images')
    part_labels_dir = os.path.join(dest_dir, f'part_{part_num}/labels')
    
    # Kiểm tra xem thư mục đã tồn tại chưa
    if os.path.exists(part_images_dir) and os.path.exists(part_labels_dir):
        print(f"Thư mục cho phần {part_num} đã tồn tại. Bỏ qua việc sao chép.")
        return

    os.makedirs(part_images_dir, exist_ok=True)
    os.makedirs(part_labels_dir, exist_ok=True)

    # Lấy danh sách tất cả các tệp hình ảnh
    all_images = os.listdir(src_images_dir)
    random.shuffle(all_images)  # Trộn ngẫu nhiên danh sách hình ảnh

    # Tính kích thước phần
    part_size = len(all_images) // total_parts
    start_index = (part_num - 1) * part_size
    end_index = start_index + part_size if part_num < total_parts else len(all_images)

    # Sao chép hình ảnh và nhãn cho phần hiện tại
    for image_name in all_images[start_index:end_index]:
        src_image_path = os.path.join(src_images_dir, image_name)
        src_label_path = os.path.join(src_labels_dir, image_name.replace('.jpg', '.txt'))  # Thay đổi đuôi tệp cho nhãn

        # Sao chép tệp hình ảnh
        shutil.copy(src_image_path, os.path.join(part_images_dir, image_name))

        # Sao chép tệp nhãn
        if os.path.exists(src_label_path):
            shutil.copy(src_label_path, os.path.join(part_labels_dir, image_name.replace('.jpg', '.txt')))
        else:
            print(f"Không tìm thấy nhãn cho hình ảnh: {image_name}")

    print(f"Đã sao chép dữ liệu cho phần {part_num}.")

def create_yaml_file(part_num, output_dir, merged_data_file):
    # Đọc tên lớp từ tệp YAML chính
    with open(merged_data_file, 'r') as f:
        yaml_data = yaml.safe_load(f)

    class_names = yaml_data.get('names', [])  # Lấy danh sách tên lớp
    num_classes = len(class_names)

    # Đường dẫn tuyệt đối tới thư mục hình ảnh
    part_images_dir = os.path.join(output_dir, f'part_{part_num}/images')

    # Chuyển đổi đường dẫn tuyệt đối sang tương đối so với thư mục hiện tại
    rel_train_images_path = os.path.relpath(part_images_dir, output_dir)

    yaml_content = f"""
train: {rel_train_images_path}
val: {rel_train_images_path}
nc: {num_classes}
names: {class_names}
"""
    yaml_path = os.path.join(output_dir, f'part_{part_num}.yaml')
    with open(yaml_path, 'w') as yaml_file:
        yaml_file.write(yaml_content.strip())

# Đường dẫn đến thư mục hình ảnh và nhãn
merged_dataset_path = os.path.join(root_directory, 'merged_dataset')
train_images_dir = os.path.join(merged_dataset_path, 'train/images')
train_labels_dir = os.path.join(merged_dataset_path, 'train/labels')

# Thư mục đích để lưu các phần dữ liệu
output_dir = os.path.join(merged_dataset_path, 'split_dataset')
os.makedirs(output_dir, exist_ok=True)

# Đường dẫn đến tệp YAML chính (merged_data.yaml)
merged_data_file = os.path.join(merged_dataset_path, 'merged_data.yaml')  # Đường dẫn đến tệp YAML

# Số phần muốn chia
num_parts = 150

# Sao chép dữ liệu cho từng phần
for i in range(1, num_parts + 1):
    copy_dataset_part(train_images_dir, train_labels_dir, output_dir, i, num_parts)
    create_yaml_file(i, output_dir, merged_data_file)  # Tạo tệp YAML cho từng phần

print(f"Đã hoàn tất chia và sao chép dữ liệu thành {num_parts} phần và tạo tệp YAML.")
# Out:
# Đã sao chép dữ liệu cho phần 1.
# Đã sao chép dữ liệu cho phần 2.
# Đã sao chép dữ liệu cho phần 3.
# Đã sao chép dữ liệu cho phần 4.
# Đã sao chép dữ liệu cho phần 5.
# Đã sao chép dữ liệu cho phần 6.
# Đã sao chép dữ liệu cho phần 7.
# Đã sao chép dữ liệu cho phần 8.
# Đã sao chép dữ liệu cho phần 9.
# Đã sao chép dữ liệu cho phần 10.
# Đã sao chép dữ liệu cho phần 11.
# Đã sao chép dữ liệu cho phần 12.
# Đã sao chép dữ liệu cho phần 13.
# Đã sao chép dữ liệu cho phần 14.
# Đã sao chép dữ liệu cho phần 15.
# Đã sao chép dữ liệu cho phần 16.
# Đã sao chép dữ liệu cho phần 17.
# Đã sao chép dữ liệu cho phần 18.
# Đã sao chép dữ liệu cho phần 19.
# Đã sao chép dữ liệu cho phần 20.
# Đã sao chép dữ liệu cho phần 21.
# Đã sao chép dữ liệu cho phần 22.
# Đã sao chép dữ liệu cho phần 23.
# Đã sao chép dữ liệu cho phần 24.
# Đã sao chép dữ liệu cho phần 25.
# Đã sao chép dữ liệu cho phần 26.
# Đã sao chép dữ liệu cho phần 27.
# Đã sao chép dữ liệu cho phần 28.
# Đã sao chép dữ liệu cho phần 29.
# Đã sao chép dữ liệu cho phần 30.
# Đã sao chép dữ liệu cho phần 31.
# Đã sao chép dữ liệu cho phần 32.
# Đã sao chép dữ liệu cho phần 33.
# Đã sao chép dữ liệu cho phần 34.
# Đã sao chép dữ liệu cho phần 35.
# Đã sao chép dữ liệu cho phần 36.
# Đã sao chép dữ liệu cho phần 37.
# Đã sao chép dữ liệu cho phần 38.
# Đã sao chép dữ liệu cho phần 39.
# Đã sao chép dữ liệu cho phần 40.
# Đã sao chép dữ liệu cho phần 41.
# Đã sao chép dữ liệu cho phần 42.
# Đã sao chép dữ liệu cho phần 43.
# Đã sao chép dữ liệu cho phần 44.
# Đã sao chép dữ liệu cho phần 45.
# Đã sao chép dữ liệu cho phần 46.
# Đã sao chép dữ liệu cho phần 47.
# Đã sao chép dữ liệu cho phần 48.
# Đã sao chép dữ liệu cho phần 49.
# Đã sao chép dữ liệu cho phần 50.
# Đã sao chép dữ liệu cho phần 51.
# Đã sao chép dữ liệu cho phần 52.
# Đã sao chép dữ liệu cho phần 53.
# Đã sao chép dữ liệu cho phần 54.
# Đã sao chép dữ liệu cho phần 55.
# Đã sao chép dữ liệu cho phần 56.
# Đã sao chép dữ liệu cho phần 57.
# Đã sao chép dữ liệu cho phần 58.
# Đã sao chép dữ liệu cho phần 59.
# Đã sao chép dữ liệu cho phần 60.
# Đã sao chép dữ liệu cho phần 61.
# Đã sao chép dữ liệu cho phần 62.
# Đã sao chép dữ liệu cho phần 63.
# Đã sao chép dữ liệu cho phần 64.
# Đã sao chép dữ liệu cho phần 65.
# Đã sao chép dữ liệu cho phần 66.
# Đã sao chép dữ liệu cho phần 67.
# Đã sao chép dữ liệu cho phần 68.
# Đã sao chép dữ liệu cho phần 69.
# Đã sao chép dữ liệu cho phần 70.
# Đã sao chép dữ liệu cho phần 71.
# Đã sao chép dữ liệu cho phần 72.
# Đã sao chép dữ liệu cho phần 73.
# Đã sao chép dữ liệu cho phần 74.
# Đã sao chép dữ liệu cho phần 75.
# Đã sao chép dữ liệu cho phần 76.
# Đã sao chép dữ liệu cho phần 77.
# Đã sao chép dữ liệu cho phần 78.
# Đã sao chép dữ liệu cho phần 79.
# Đã sao chép dữ liệu cho phần 80.
# Đã sao chép dữ liệu cho phần 81.
# Đã sao chép dữ liệu cho phần 82.
# Đã sao chép dữ liệu cho phần 83.
# Đã sao chép dữ liệu cho phần 84.
# Đã sao chép dữ liệu cho phần 85.
# Đã sao chép dữ liệu cho phần 86.
# Đã sao chép dữ liệu cho phần 87.
# Đã sao chép dữ liệu cho phần 88.
# Đã sao chép dữ liệu cho phần 89.
# Đã sao chép dữ liệu cho phần 90.
# Đã sao chép dữ liệu cho phần 91.
# Đã sao chép dữ liệu cho phần 92.
# Đã sao chép dữ liệu cho phần 93.
# Đã sao chép dữ liệu cho phần 94.
# Đã sao chép dữ liệu cho phần 95.
# Đã sao chép dữ liệu cho phần 96.
# Đã sao chép dữ liệu cho phần 97.
# Đã sao chép dữ liệu cho phần 98.
# Đã sao chép dữ liệu cho phần 99.
# Đã sao chép dữ liệu cho phần 100.
# Đã sao chép dữ liệu cho phần 101.
# Đã sao chép dữ liệu cho phần 102.
# Đã sao chép dữ liệu cho phần 103.
# Đã sao chép dữ liệu cho phần 104.
# Đã sao chép dữ liệu cho phần 105.
# Đã sao chép dữ liệu cho phần 106.
# Đã sao chép dữ liệu cho phần 107.
# Đã sao chép dữ liệu cho phần 108.
# Đã sao chép dữ liệu cho phần 109.
# Đã sao chép dữ liệu cho phần 110.
# Đã sao chép dữ liệu cho phần 111.
# Đã sao chép dữ liệu cho phần 112.
# Đã sao chép dữ liệu cho phần 113.
# Đã sao chép dữ liệu cho phần 114.
# Đã sao chép dữ liệu cho phần 115.
# Đã sao chép dữ liệu cho phần 116.
# Đã sao chép dữ liệu cho phần 117.
# Đã sao chép dữ liệu cho phần 118.
# Đã sao chép dữ liệu cho phần 119.
# Đã sao chép dữ liệu cho phần 120.
# Đã sao chép dữ liệu cho phần 121.
# Đã sao chép dữ liệu cho phần 122.
# Đã sao chép dữ liệu cho phần 123.
# Đã sao chép dữ liệu cho phần 124.
# Đã sao chép dữ liệu cho phần 125.
# Đã sao chép dữ liệu cho phần 126.
# Đã sao chép dữ liệu cho phần 127.
# Đã sao chép dữ liệu cho phần 128.
# Đã sao chép dữ liệu cho phần 129.
# Đã sao chép dữ liệu cho phần 130.
# Đã sao chép dữ liệu cho phần 131.
# Đã sao chép dữ liệu cho phần 132.
# Đã sao chép dữ liệu cho phần 133.
# Đã sao chép dữ liệu cho phần 134.
# Đã sao chép dữ liệu cho phần 135.
# Đã sao chép dữ liệu cho phần 136.
# Đã sao chép dữ liệu cho phần 137.
# Đã sao chép dữ liệu cho phần 138.
# Đã sao chép dữ liệu cho phần 139.
# Đã sao chép dữ liệu cho phần 140.
# Đã sao chép dữ liệu cho phần 141.
# Đã sao chép dữ liệu cho phần 142.
# Đã sao chép dữ liệu cho phần 143.
# Đã sao chép dữ liệu cho phần 144.
# Đã sao chép dữ liệu cho phần 145.
# Đã sao chép dữ liệu cho phần 146.
# Đã sao chép dữ liệu cho phần 147.
# Đã sao chép dữ liệu cho phần 148.
# Đã sao chép dữ liệu cho phần 149.
# Đã sao chép dữ liệu cho phần 150.
# Đã hoàn tất chia và sao chép dữ liệu thành 150 phần và tạo tệp YAML.
